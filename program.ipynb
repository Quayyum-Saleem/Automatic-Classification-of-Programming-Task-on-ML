# %%
import pandas as pd

df = pd.read_csv("D:/Automatic Error Detector/Dataset/dataset_upto500.csv")

print("Number of programs:", len(df))

print("\nColumns:")
print(df.columns)

print("\nError distribution:")
print(df["error_type"].value_counts())

print("\nDataset:")
print(df)
# Out:
# Number of programs: 500
#
# Columns:
# Index(['id', 'task_id', 'task', 'code', 'error_type'], dtype='str')
#
# Error distribution:
# error_type
# Update_Error            100
# Correct                 100
# Initialization_Error    100
# Infinite_Loop           100
# Condition_Error         100
# Name: count, dtype: int64
#
# Dataset:
#       id  task_id                                   task  \
# 0    362        6        Calculate factorial of a number
# 1     74        2        Print even numbers from 2 to 20
# 2    375        3         Print odd numbers from 1 to 19
# 3    156        8                       Reverse a number
# 4    105        5  Print numbers from 10 to 1 in reverse
# ..   ...      ...                                    ...
# 495  107        7               Count digits in a number
# 496  271        7               Count digits in a number
# 497  349        1             Print numbers from 1 to 10
# 498  436        4   Calculate sum of numbers from 1 to N
# 499  103        3         Print odd numbers from 1 to 19
#
#                                                   code            error_type
# 0    n = 5\ni = 1\nfact = 1\nwhile i <= n:\n    fac...          Update_Error
# 1    i = 2\nwhile i <= 20:\n    print(i)\n    i = i...               Correct
# 2    i = 1\nwhile i <= 19:\n    print(i)\n    i = i...          Update_Error
# 3    n = 12345\nreverse = 1\nwhile n > 0:\n    digi...  Initialization_Error
# 4    i = 1\nwhile i >= 1:\n    print(i)\n    i = i - 1  Initialization_Error
# ..                                                 ...                   ...
# 495  n = 12345\ncount = 1234\nwhile n > 0:\n    cou...  Initialization_Error
# 496  n = 12345\ncount = 0\nwhile n >= 0:\n    count...       Condition_Error
# 497  i = 1\nwhile i <= 10:\n    print(i)\n    i = i...          Update_Error
# 498  n = 10\ni = 1\ntotal = 0\nwhile i <= n:\n    t...         Infinite_Loop
# 499  i = 4\nwhile i <= 19:\n    print(i)\n    i = i...  Initialization_Error
#
# [500 rows x 5 columns]
